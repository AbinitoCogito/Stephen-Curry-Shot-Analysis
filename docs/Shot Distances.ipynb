# %%
figs, axes = plt.subplots()
distances = ['Less than 8 ft.', '8-16 ft.', '16-24 ft.', '24ft+', 'Back Court Shot']
counts = [351, 126, 218, 638, 8]
bar_labels = ['red', 'blue', 'purple', 'orange', 'black']
bar_colors = ['tab:red', 'tab:blue', 'tab:purple', 'tab:orange', 'black']

axes.bar(distances, counts, label=bar_labels, color=bar_colors)
axes.set_ylabel('Frequency')
axes.set_title('Shot Distances By Colors')
axes.legend(title='Fruit color')
plt.show()

# %% [markdown]
# The NBA has a 22-foot 3-point line in the corners and a 23-foot, 9-inch line elsewhere.Curry most known for firing threes from far away the hoop. This graphs indicates that Curry takes 3-point shots over 2-point shots. One can consider less than 8 feet's are the lay-ups, bank shots and floaters.

# %% [markdown]
# According to Olivier Chabot in his spatial and basketball shots analysis work (https://duddhawork.com/ballbook/model.html), the expected points should embrace possesions quality order is : 2 or more free throws
#
# lay ups
# >
# 3-pointer r
# >
# mid ranger. When we look at Curry's resume, I say that he selected his shots as optimal who has a great shooting ability.
