# %%
three_shots = Curry[Curry['SHOT_TYPE'] == '3PT Field Goal']
three_per = three_shots['SHOT_MADE_FLAG'].sum() / three_shots['SHOT_MADE_FLAG'].size
print(f'Stephen Curry 3PTM percentage: {three_per}')

event_counts = three_shots['EVENT_TYPE'].value_counts()
plt.bar(event_counts.index, event_counts.values, edgecolor='black', alpha=0.75)
plt.title('Stephen Curry 3PT FGA Bar Graphic', fontsize=16)
plt.xlabel('3PT FG', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=0)
plt.show()
# Out:
# Stephen Curry 3PTM percentage: 0.44272445820433437

# %% [markdown]
# 0.44% is impressive 3 point percentage performance. Interestingly, the head coach of the Warriors Steve Kerr had 0.45% from the 3 point line. With the Kerr's coming, he and the team changed to game style to motion offense and 3 point shooting. When you look the simultenous change Curry's game, maybe there needed to be a man who understands Curry's language and his extraordinary potential.
