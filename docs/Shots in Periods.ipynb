# %% [markdown]
# As we see in the bar graph, Curry tend to take shots first half. He shoots the ball with 0.48 chance beginning of the match. In the second half, he looks like more controlled and maybe looks for true shot position for himself and teammates.

# %%
figx, axex = plt.subplots()
distances = [1,2,3,4,5]
counts = [456, 407, 237, 234, 7]
bar_labels = ['1th Period', '2nd Period', '3rd Period', '4th Period', 'OT']
bar_colors = ['tab:red', 'tab:blue', 'tab:purple', 'tab:orange', 'black']

axex.bar(distances, counts, label=bar_labels, color=bar_colors)

axex.set_ylabel('Frequency')
axex.set_title('Shots in Periods By Colors')
axex.legend(title='Period Color')

plt.show()
