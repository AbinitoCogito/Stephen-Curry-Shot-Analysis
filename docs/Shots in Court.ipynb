# %% [markdown]
# The dataset includes the shots locations as X and Y 's. Considering the hoop center as (X = 0, Y = 0), I scatter plotted the shots. The density of 3 point shot locations can easily observed.

# %%
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))
plt.scatter(Curry.LOC_X, Curry.LOC_Y)
plt.show()

# %%
left = Curry[(Curry['SHOT_ZONE_AREA'] == 'Left Side(L)') | (Curry['SHOT_ZONE_AREA'] == 'Left Side Center(LC)')]
plt.figure(figsize=(12,11))
plt.scatter(left.LOC_X, left.LOC_Y)
plt.xlim(-300,300)
plt.ylim(-100,500)
plt.show()

# %%
left_per = left['SHOT_MADE_FLAG'].sum() / left['SHOT_MADE_FLAG'].size
print(f'Stephen Curry all shots from the left side percentage: {left_per}')
# Out:
# Stephen Curry all shots from the left side percentage: 0.46875

# %%
right = Curry[(Curry['SHOT_ZONE_AREA'] == 'Right Side(R)') | (Curry['SHOT_ZONE_AREA'] == 'Right Side Center(RC)')]
plt.figure(figsize=(12,11))
plt.scatter(right.LOC_X, right.LOC_Y)
plt.xlim(-300,300)
plt.ylim(-100,500)
plt.show()

# %%
right_per = right['SHOT_MADE_FLAG'].sum() / right['SHOT_MADE_FLAG'].size
print(f'Stephen Curry all shots from the right side percentage: {right_per}')
# Out:
# Stephen Curry all shots from the right side percentage: 0.42063492063492064

# %% [markdown]
# The difference from left and side may be explained by one article that belongs to Alan Marty, founder of Noah Basketball, indicates that systematic shoot bias. On average, players shooting from the right corner shoots 2.34 inches left of the hoop center. On average, players shooting from the left corner shoot 1.0 inches right of the hoop center. This may happen because right-handed players dominant against left-handed players.
